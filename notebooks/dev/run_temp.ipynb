# %%
# %load_ext autoreload
# %autoreload 2

import concurrent.futures
from cmipper import utils, config, parallelised_download_and_process, file_ops
import xarray as xa

from tqdm.auto import tqdm
from coralshift.plotting import spatial_plots


parallelised_download_and_process.main(source_id="MPI-ESM1-2-HR", variable_id="po4")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# TIME CREATED: 2024-06-15 11:26:52
#
# Processing data for MPI-ESM1-2-HR, r1i1p1f1, po4
#
#
#
# po4: searching ESGF servers
#
# found historical, [1850, 2015]
# found 33 files on esgf-data1.llnl.gov node of which 33
#             fall(s) within required date range.
# downloading individual files
# 	0: existing regridded file found at /maps-priv/maps/rt582/cmipper/data/env_vars/cmip6/MPI-ESM1-2-HR/r1i1p1f1/regridded/po4/po4_uncropped_sfl-20_ll_190001-190412.nc
# 	0: skipping regrid due to existing file: /maps-priv/maps/rt582/cmipper/data/env_vars/cmip6/MPI-ESM1-2-HR/r1i1p1f1/regridded/po4/po4_uncropped_sfl-20_ll_190001-190412.nc
# 	1: existing regridded file found at /maps-priv/maps/rt582/cmipper/data/env_vars/cmip6/MPI-ESM1-2-HR/r1i1p1f1/regridded/po4/po4_uncropped_sfl-20_ll_191501-191912.nc
# ...

# %%
xa.open_dataset("/maps/rt582/cmipper/data/env_vars/cmip6/MPI-ESM1-2-HR/r1i1p1f1/regridded/po4/po4_uncropped_sfl-20_ll_197501-197912.nc")
# Out:
# <xarray.Dataset> Size: 78MB
# Dimensions:    (time: 60, bnds: 2, lon: 802, lat: 404)
# Coordinates:
#   * time       (time) datetime64[ns] 480B 1975-01-16T12:00:00 ... 1979-12-16T...
#   * lon        (lon) float64 6kB -180.0 -179.5 -179.1 ... 178.7 179.1 179.6
#   * lat        (lat) float64 3kB -78.72 -78.3 -77.88 ... 88.51 88.93 89.35
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] 960B ...
#     po4        (time, lat, lon) float32 78MB ...
# Attributes: (12/50)
#     CDI:                             Climate Data Interface version 2.4.0 (ht...
#     Conventions:                     CF-1.7 CMIP-6.2
#     source:                          MPI-ESM1.2-HR (2017): \naerosol: none, p...
#     institution:                     Max Planck Institute for Meteorology, Ha...
#     activity_id:                     CMIP
#     branch_method:                   standard
#     ...                              ...
# ...
